# %% [markdown]
#  Import necessary libraries for data analysis and visualization

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Load the "Superstore Sales" dataset from a CSV file into a Pandas DataFrame for further analysis, using latin1 encoding to handle special characters in the data.

# %%
store_data = pd.read_csv("C:/Users/SHAHZOR AHMED/OneDrive/Desktop/Full Stack Academy/Superstore-Sales.csv", encoding= 'latin1')
store_data
# Out:
#       Row ID  Order ID  Order Date Order Priority  Order Quantity       Sales  \
# 0          1         3  10/13/2010            Low               6    261.5400
# 1         49       293   10/1/2012           High              49  10123.0200
# 2         50       293   10/1/2012           High              27    244.5700
# 3         80       483   7/10/2011           High              30   4965.7595
# 4         85       515   8/28/2010  Not Specified              19    394.2700
# ...      ...       ...         ...            ...             ...         ...
# 8394    7765     55558    8/9/2010         Medium               8   1294.0400
# 8395    7766     55558    8/9/2010         Medium              23    392.5700
# 8396    7906     56550    4/8/2011  Not Specified              37    823.7800
# 8397    7907     56550    4/8/2011  Not Specified               8    469.8375
# 8398    7914     56581    2/8/2009           High              20   2026.0100
#
# ...

# %% [markdown]
# Retrieve the dimensions of the dataset, which includes the number of rows and columns in the DataFrame.

# %%
store_data.shape
# Out:
# (8399, 21)

# %% [markdown]
# Find the maximum and minimum sales value in the "Sales" column of the dataset.

# %%
store_data['Sales'].max()
# Out:
# 89061.05

# %%
store_data['Sales'].min()
# Out:
# 2.24

# %% [markdown]
# Generate descriptive statistics for the dataset, including count, mean, standard deviation, minimum, maximum, and percentile values for numerical columns. This provides a summary of the dataset's distribution and key metrics.

# %%
store_data.describe()
# Out:
#             Row ID      Order ID  Order Quantity         Sales     Discount  \
# count  8399.000000   8399.000000     8399.000000   8399.000000  8399.000000
# mean   4200.000000  29965.179783       25.571735   1775.878179     0.049671
# std    2424.726789  17260.883447       14.481071   3585.050525     0.031823
# min       1.000000      3.000000        1.000000      2.240000     0.000000
# 25%    2100.500000  15011.500000       13.000000    143.195000     0.020000
# 50%    4200.000000  29857.000000       26.000000    449.420000     0.050000
# 75%    6299.500000  44596.000000       38.000000   1709.320000     0.080000
# max    8399.000000  59973.000000       50.000000  89061.050000     0.250000
#
#              Profit   Unit Price  Shipping Cost  Product Base Margin
# count   8399.000000  8399.000000    8399.000000          8336.000000
# mean     181.184424    89.346259      12.838557             0.512513
# std     1196.653371   290.354383      17.264052             0.135589
# ...

# %% [markdown]
# Create a count plot using Seaborn to visualize the distribution of products across different categories in the "Product Category" column.

# %%
sns.countplot(data= store_data , x = store_data['Product Category'])
# Out:
# <Axes: xlabel='Product Category', ylabel='count'>

# %% [markdown]
#  Generate a count plot to visualize the distribution of products across the "Product Sub-Category" column.

# %%
sns.countplot(data= store_data, x = store_data['Product Sub-Category'])
plt.xticks(rotation = 90)
plt.plot()
# Out:
# []

# %% [markdown]
# Visualize the distribution of data across the "Region" column using a count plot, showing the frequency of records in each region.

# %%
sns.countplot(data= store_data, x = store_data['Region'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Count the occurrences of each unique value in the "Product Category" column to determine the frequency of each product category in the dataset.

# %%
store_data['Product Category'].value_counts()
# Out:
# Product Category
# Office Supplies    4610
# Technology         2065
# Furniture          1724
# Name: count, dtype: int64

# %% [markdown]
# Create a bar plot to visualize the relationship between regions (x-axis) and profit (y-axis).

# %%
sns.barplot(data= store_data, x = store_data['Region'], y = store_data['Profit'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Create a bar plot to visualize the average profit (y-axis) for each region (x-axis), further categorized by "Product Category" using the hue parameter.

# %%
sns.barplot(data= store_data, x = store_data['Region'], y = store_data['Profit'], hue = store_data['Product Category'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Generate a scatter plot to visualize the relationship between "Sales" (x-axis) and "Profit" (y-axis) in the dataset.

# %%
sns.scatterplot(data= store_data , x = store_data['Sales'], y = store_data['Profit'])
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %% [markdown]
# Create a joint plot to visualize the relationship between "Sales" (x-axis) and "Profit" (y-axis). This plot provides a combination of scatter plot and histograms to show both the data distribution and the correlation between the two variables.

# %%
sns.jointplot(data= store_data, x = store_data['Sales'], y = store_data['Profit'])

# %% [markdown]
# Create a regression plot to visualize the linear relationship between "Sales" (x-axis) and "Profit" (y-axis).

# %%
sns.regplot(data= store_data, x = store_data['Sales'], y = store_data['Profit'])
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %% [markdown]
# Generate a scatter plot to visualize the relationship between "Sales" (x-axis) and "Profit" (y-axis), with data points color-coded by "Product Category" using the hue parameter.

# %%
sns.scatterplot(data= store_data , x = store_data['Sales'], y = store_data['Profit'], hue= store_data['Product Category'])
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %% [markdown]
# Create a scatter plot to visualize the relationship between "Sales" (x-axis) and "Profit" (y-axis), with data points color-coded by "Region" using the hue parameter.

# %%
sns.scatterplot(data = store_data , x = store_data['Sales'], y = store_data['Profit'], hue= store_data['Region'])
# Out:
# <Axes: xlabel='Sales', ylabel='Profit'>

# %%
sns.barplot(data= store_data, x = store_data['Product Category'], y = store_data['Sales'], hue= store_data['Ship Mode'])
# Out:
# <Axes: xlabel='Product Category', ylabel='Sales'>

# %% [markdown]
# Extract the year component from the "Order Date" column in the dataset by converting it to a DatetimeIndex. This allows for further analysis based on the year of the orders.

# %%
pd.DatetimeIndex(store_data['Order Date']).year
# Out:
# Index([2010, 2012, 2012, 2011, 2010, 2010, 2011, 2011, 2011, 2010,
#        ...
#        2012, 2009, 2010, 2012, 2011, 2010, 2010, 2011, 2011, 2009],
#       dtype='int32', name='Order Date', length=8399)

# %% [markdown]
# Extract the month component from the "Order Date" column in the dataset by converting it to a DatetimeIndex. This enables month-wise analysis of the orders.

# %%
pd.DatetimeIndex(store_data['Order Date']).month
# Out:
# Index([10, 10, 10,  7,  8,  8,  6,  6,  3,  2,
#        ...
#         9,  9, 10,  7,  7,  8,  8,  4,  4,  2],
#       dtype='int32', name='Order Date', length=8399)

# %% [markdown]
# Add a new column, "Order Month," to the dataset by extracting the month component from the "Order Date" column.

# %%
store_data['Order Month'] = pd.DatetimeIndex(store_data['Order Date']).month
store_data.head()
# Out:
#    Row ID  Order ID  Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3  10/13/2010            Low               6    261.5400
# 1      49       293   10/1/2012           High              49  10123.0200
# 2      50       293   10/1/2012           High              27    244.5700
# 3      80       483   7/10/2011           High              30   4965.7595
# 4      85       515   8/28/2010  Not Specified              19    394.2700
#
#    Discount       Ship Mode   Profit  Unit Price  ...  Province   Region  \
# 0      0.04     Regular Air  -213.25       38.94  ...   Nunavut  Nunavut
# 1      0.07  Delivery Truck   457.81      208.16  ...   Nunavut  Nunavut
# 2      0.01     Regular Air    46.71        8.69  ...   Nunavut  Nunavut
# 3      0.08     Regular Air  1198.97      195.99  ...   Nunavut  Nunavut
# 4      0.08     Regular Air    30.94       21.78  ...   Nunavut  Nunavut
#
#   Customer Segment Product Category            Product Sub-Category  \
# ...

# %% [markdown]
# Add a new column, "Order Year," to the dataset by extracting the year component from the "Order Date" column.

# %%
store_data['Order Year'] = pd.DatetimeIndex(store_data['Order Date']).year
store_data.head()
# Out:
#    Row ID  Order ID  Order Date Order Priority  Order Quantity       Sales  \
# 0       1         3  10/13/2010            Low               6    261.5400
# 1      49       293   10/1/2012           High              49  10123.0200
# 2      50       293   10/1/2012           High              27    244.5700
# 3      80       483   7/10/2011           High              30   4965.7595
# 4      85       515   8/28/2010  Not Specified              19    394.2700
#
#    Discount       Ship Mode   Profit  Unit Price  ...   Region  \
# 0      0.04     Regular Air  -213.25       38.94  ...  Nunavut
# 1      0.07  Delivery Truck   457.81      208.16  ...  Nunavut
# 2      0.01     Regular Air    46.71        8.69  ...  Nunavut
# 3      0.08     Regular Air  1198.97      195.99  ...  Nunavut
# 4      0.08     Regular Air    30.94       21.78  ...  Nunavut
#
#   Customer Segment Product Category            Product Sub-Category  \
# ...

# %% [markdown]
# Create a line plot to visualize the trend of "Profit" (y-axis) over the years (x-axis) using the "Order Year" column.

# %%
sns.lineplot(data= store_data , x = store_data['Order Year'], y = store_data['Profit'])
# Out:
# <Axes: xlabel='Order Year', ylabel='Profit'>

# %% [markdown]
# Generate a line plot to analyze the trend of "Profit" (y-axis) across different months (x-axis) using the "Order Month" column.

# %%
sns.lineplot(data= store_data, x = store_data['Order Month'] , y = store_data['Profit'])
# Out:
# <Axes: xlabel='Order Month', ylabel='Profit'>

# %% [markdown]
# Create a line plot to visualize the trend of "Sales" (y-axis) over the years (x-axis) using the "Order Year" column.

# %%
sns.lineplot(data= store_data , x = store_data['Order Year'], y = store_data['Sales'])
# Out:
# <Axes: xlabel='Order Year', ylabel='Sales'>

# %% [markdown]
# Create a line plot to visualize the trend of "Profit" (y-axis) across different months (x-axis) using the "Order Month" column.

# %%
sns.lineplot(data= store_data , x = store_data['Order Month'], y = store_data['Profit'])
# Out:
# <Axes: xlabel='Order Month', ylabel='Profit'>

# %% [markdown]
# Create a box plot to visualize the distribution, spread, and potential outliers in the "Order Quantity" column. This helps in understanding the central tendency and variability of order quantities in the dataset.

# %%
sns.boxplot(data= store_data['Order Quantity'])
# Out:
# <Axes: ylabel='Order Quantity'>

# %% [markdown]
# Create a bar plot to visualize the total sales (y-axis) for each product sub-category (x-axis).

# %%
sns.barplot(data= store_data , x = store_data['Product Sub-Category'], y = store_data['Sales'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Generate a bar plot with a larger figure size (10x9) to better display the sales data across different product sub-categories. The x-axis labels are rotated 90 degrees for improved readability. This visual helps in identifying variations in sales among the sub-categories.

# %%
plt.figure(figsize=(10,9))
sns.barplot(data= store_data, x = store_data['Product Sub-Category'], y = store_data['Sales'])
plt.xticks(rotation = 90)
plt.plot()
# Out:
# []

# %% [markdown]
# Generate a bar plot with a figure size of 10x9 to visualize the profit (y-axis) for each product sub-category (x-axis). The x-axis labels are rotated 90 degrees to enhance readability, helping to identify which sub-categories are most or least profitable.

# %%
plt.figure(figsize=(10,9))
sns.barplot(data= store_data, x = store_data['Product Sub-Category'], y = store_data['Profit'])
plt.xticks(rotation = 90)
plt.plot()
# Out:
# []
