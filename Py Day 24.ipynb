# %% [markdown]
# Import essential libraries for data analysis and visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Plot a line chart using the x and y values to visualize the relationship between these data points.

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]
plt.plot(x , y)

# %% [markdown]
# Plot a line chart using the x and y values to visualize the relationship between these data points.

# %%
x = range(1,10)
y = [1,2,3,4,2,4,3,2,1]
plt.plot(x , y)

# %% [markdown]
# Plot a line chart using the x and y values to visualize the relationship between these data points.

# %%
x = range(1,10)
y = [10,6,2,0,2,6,10,11,12]
plt.plot(x , y)

# %% [markdown]
# Load the "cars" dataset into a Pandas DataFrame and rename its columns for clarity and consistency

# %%
cars = pd.read_csv("C:/Users/SHAHZOR AHMED/OneDrive/Desktop/Full Stack Academy/cars.csv")
cars.columns = ['Cars_names',	'mpg'	,'cyl'	,'disp'	,'hp'	,'drat'	,'wt'	,'qsec'	,'vs'	,'am'	,'gear',	'carb']
cars
# Out:
#              Cars_names   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %% [markdown]
# Extract the "mpg" (miles per gallon) column from the "cars" dataset into a separate variable mpg_data.

# %%
mpg_data = cars.mpg
mpg_data
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %% [markdown]
# Plot the "mpg" (miles per gallon) data to visualize trends or patterns in vehicle fuel efficiency across the dataset.

# %%
mpg_data.plot()
# Out:
# <Axes: >

# %% [markdown]
# Extract the "wt" (weight) column from the "cars" dataset into a separate variable wt_data.

# %%
wt_data = cars.wt
wt_data
# Out:
# 0     2.620
# 1     2.875
# 2     2.320
# 3     3.215
# 4     3.440
# 5     3.460
# 6     3.570
# 7     3.190
# 8     3.150
# 9     3.440
# 10    3.440
# 11    4.070
# 12    3.730
# 13    3.780
# 14    5.250
# 15    5.424
# 16    5.345
# 17    2.200
# 18    1.615
# 19    1.835
# 20    2.465
# 21    3.520
# 22    3.435
# 23    3.840
# 24    3.845
# 25    1.935
# 26    2.140
# 27    1.513
# 28    3.170
# 29    2.770
# 30    3.570
# 31    2.780
# Name: wt, dtype: float64

# %% [markdown]
#  Plot the "wt" (weight) data to visualize trends or variations in vehicle weight across the dataset.

# %%
wt_data.plot()
# Out:
# <Axes: >

# %% [markdown]
# Extract the "mpg" (miles per gallon) and "wt" (weight) columns from the dataset into a new DataFrame, cars_mpg_wt_data. Then, plot both columns to visualize their trends and potential relationships.

# %%
cars_mpg_wt_data = cars[['mpg','wt']]
cars_mpg_wt_data.plot()
# Out:
# <Axes: >

# %% [markdown]
# Extract the "mpg" (miles per gallon), "wt" (weight), and "cyl" (cylinders) columns from the dataset into a new DataFrame, cars_mpg_wt_cyl_data. Then, plot the data to visualize and compare trends or patterns across these three variables.

# %%
cars_mpg_wt_cyl_data = cars[['mpg', 'wt', 'cyl']]
cars_mpg_wt_cyl_data.plot()
# Out:
# <Axes: >

# %% [markdown]
# Load the "india_vs_pakistan_scores" dataset into a Pandas DataFrame named ind_pak_data.

# %%
ind_pak_data = pd.read_csv("C:/Users/SHAHZOR AHMED/OneDrive/Desktop/Full Stack Academy/india_vs_pakistan_scores..csv")
ind_pak_data
# Out:
#     overs  india_scores  pakistan_scores
# 0       1             0                0
# 1       2             4                6
# 2       3            10                8
# 3       4            16               14
# 4       5            22               25
# 5       6            28               26
# 6       7            34               32
# 7       8            40               38
# 8       9            48               44
# 9      10            54               56
# 10     11            60               56
# 11     12            66               62
# 12     13            72               68
# 13     14            78               74
# 14     15            84               90
# 15     16            90               90
# 16     17            96               92
# 17     18           102               98
# 18     19           108              104
# 19     20           114              110
# 20     21           120              121
# 21     22           126              122
# ...

# %% [markdown]
# Extract the "india_scores" and "pakistan_scores" columns from the dataset into a new DataFrame, ind_pak_score. Plot these columns to visualize and compare the scoring trends of India and Pakistan over the matches.

# %%
ind_pak_score = ind_pak_data[['india_scores', 'pakistan_scores']]
ind_pak_score.plot()
# Out:
# <Axes: >

# %% [markdown]
# Create a bar chart using x as the categories and y as their respective values. This visualization highlights the distribution or frequency of values in a categorical format.

# %%
x = range(1,10)
y = [1,2,3,4,0,4,3,2,1]
plt.bar(x ,y)
plt.show()

# %% [markdown]
# Create a bar chart using x as the categories and y as their respective values. This visualization highlights the distribution or frequency of values in a categorical format.

# %%
x = range(1, 10)
y = [1, 2, 3, 4, 6, 4, 3, 2, 1]
plt.bar(x, y)
# Out:
# <BarContainer object of 9 artists>

# %% [markdown]
# Create a bar chart to visualize the "mpg" (miles per gallon) data, showing the fuel efficiency of each vehicle in a categorical format. Using kind='bar' ensures the data is represented as vertical bars.

# %%
mpg_data.plot(kind= 'bar')
# Out:
# <Axes: >

# %% [markdown]
# Create a horizontal bar chart to visualize the "mpg" (miles per gallon) data. Using kind='barh' ensures the data is represented as horizontal bars, which can improve readability for large datasets or long labels.

# %%
mpg_data.plot(kind= 'barh')
# Out:
# <Axes: >

# %% [markdown]
# Create a pie chart to represent the proportions of the elements in x with corresponding labels ['A', 'B', 'C', 'D', 'E']. This visualization helps illustrate the relative sizes of the values in a circular format.

# %%
x = [1,2,3,4,0.5]
plt.pie(x ,labels= ['A','B','C','D','E'])
plt.show()

# %% [markdown]
# Create a pie chart to represent the proportions of the elements in x with labels ['A', 'B', 'C', 'D', 'E']. Save the plot as an image file named "pie chart of random numbers.png"

# %%
x = [1,2,3,4,0.5]
plt.pie(x ,labels= ['A','B','C','D','E'])
plt.savefig("pie chart of random numbers.png")
plt.show()

# %% [markdown]
# Load the "20 over india_vs_pakistan_scores" dataset from the specified file path into a Pandas DataFrame named IND_PAK_20.

# %%
address = "C:/Users/SHAHZOR AHMED/OneDrive/Desktop/Full Stack Academy/20 over india_vs_pakistan_scores..csv"
IND_PAK_20 = pd.read_csv(address)
IND_PAK_20
# Out:
#     overs  india_scores  pakistan_scores
# 0       1             0                0
# 1       2             4                6
# 2       3            10                8
# 3       4            16               14
# 4       5            22               25
# 5       6            28               26
# 6       7            34               32
# 7       8            40               38
# 8       9            48               44
# 9      10            54               56
# 10     11            60               56
# 11     12            66               62
# 12     13            72               68
# 13     14            78               74
# 14     15            84               90
# 15     16            90               90
# 16     17            96               92
# 17     18           102               98
# 18     19           108              104
# 19     20           160              120

# %% [markdown]
# Extract the "india_scores" and "pakistan_scores" columns from the IND_PAK_20 DataFrame into a new DataFrame named IND_PAK_20_SCORE. This isolates the scores for focused analysis or comparison between India and Pakistan in 20-over matches.

# %%
IND_PAK_20_SCORE  = IND_PAK_20[['india_scores', 'pakistan_scores']]
IND_PAK_20_SCORE
# Out:
#     india_scores  pakistan_scores
# 0              0                0
# 1              4                6
# 2             10                8
# 3             16               14
# 4             22               25
# 5             28               26
# 6             34               32
# 7             40               38
# 8             48               44
# 9             54               56
# 10            60               56
# 11            66               62
# 12            72               68
# 13            78               74
# 14            84               90
# 15            90               90
# 16            96               92
# 17           102               98
# 18           108              104
# 19           160              120

# %% [markdown]
# Plot the scores of India and Pakistan from the IND_PAK_20_SCORE DataFrame to visualize and compare their scoring trends over 20-over matches. The plt.show() function ensures the plot is displayed.

# %%
IND_PAK_20_SCORE.plot()
plt.show()
